# %% [markdown]
# # Exercise 2.A Using built-in fuctions
# ## Lab 1. working with names - parsing strings

# %%
test_name = 'John Doe'

# %%
def parse_and_display(name):
    
    for i in range(len(name)):
        if name[i] == ' ':
            first = name[:i]
            last = name[i+1:]
            
            print(f"Full name: {name}")
            print(f"First name: {first}")
            print(f"Last name: {last}")

parse_and_display("John Doe")
# Out:
# Full name: John Doe
# First name: John
# Last name: Doe

# %%
test_list = ['Grace Flores', 'JB Oinonen', 'Ken Penn']

# %%
parse_and_display(test_list[0])
# Out:
# Full name: Grace Flores
# First name: Grace
# Last name: Flores

# %%
parse_and_display(test_list[1])
# Out:
# Full name: JB Oinonen
# First name: JB
# Last name: Oinonen

# %%
parse_and_display(test_list[2])
# Out:
# Full name: Ken Penn
# First name: Ken
# Last name: Penn

# %%
# inputting my name 
test_list = 'Myleah Richardson'

# %%
parse_and_display(test_list)
# Out:
# Full name: Myleah Richardson
# First name: Myleah
# Last name: Richardson

# %% [markdown]
# CHALLENGE

# %%
test_list2 = ['Micheal Jackson', 'Summer Walker', 'Tory Lanez']

# %%
def parse_and_display2(name):

    for i in range(len(name)):
        if name[i] == ' ':
            first = name[:i]
            last = name[i+1:]

            print(f"Full name: {name}")
            print(f"First name: {first}")
            print(f"Last name: {last}")

# %%
parse_and_display2(test_list2[0])
# Out:
# Full name: Micheal Jackson
# First name: Micheal
# Last name: Jackson

# %%
parse_and_display2(test_list2[1])
# Out:
# Full name: Summer Walker
# First name: Summer
# Last name: Walker

# %%
parse_and_display2(test_list2[2])
# Out:
# Full name: Tory Lanez
# First name: Tory
# Last name: Lanez
