# %% [markdown]
# # Lab 1 of Exercise 2.C

# %%
def favorite_thing(name, movie, music):
    return f"Name: {name}\nFavorite Movie: {movie}\nFavorite Musician/Band: {music}"

print(favorite_thing("Myleah", "Ratatouille", "Drake"))
# Out:
# Name: Myleah
# Favorite Movie: Ratatouille
# Favorite Musician/Band: Drake

# %%
#creating function 

def why_im_here(purpose):
    return f"I am here{purpose}."

# Call the function
print(why_im_here ("I joined the Year Up United Data Analyst program to build my data and technology skills for a future career in analytics"))
# Out:
# I am hereI joined the Year Up United Data Analyst program to build my data and technology skills for a future career in analytics.

# %%
# Create the function
def favorite_place(place, why):
    return f"One of my favorite places is {place} because {why}."

# %%
print(favorite_place(
    "New York City",
    "there are many things to do and amazing food places"
))
# Out:
# One of my favorite places is New York City because there are many things to do and amazing food places.

# %%
#One of my favorite places is New York City because there are many things to do and amazing food places.

# %%
print(favorite_place(
    "Miami",
    "I enjoy the beaches and warm weather"
))
# Out:
# One of my favorite places is Miami because I enjoy the beaches and warm weather.
